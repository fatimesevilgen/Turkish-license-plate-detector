# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt') # yolov8n.pt modelini yükle

# %%
model.train(data='data.yml', epochs=3, imgsz=640, batch=8, device="cpu") # 3 epoch boyunca eğit
# Out:
# Ultralytics 8.3.141  Python-3.11.5 torch-2.7.0+cu128 CPU (13th Gen Intel Core(TM) i7-13650HX)
# ...
